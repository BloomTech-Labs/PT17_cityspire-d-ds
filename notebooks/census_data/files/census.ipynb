# %% [markdown]
# # CENSUS DATA

# %% [markdown]
# Assumptions:
# - When getting demographic info, assumed the percentages were from the total population
# - With employment related statistics, assumed the percentages were from the total employed.

# %% [markdown]
# # EDA

# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %% [markdown]
# ### Import data

# %% [markdown]
# ##### Zip Code Data
# - using for city information

# %%
uszip = pd.read_csv('/content/uszips.csv')

# %%
print(uszip.shape)
uszip.head()
# Out:
# (33121, 18)
#    zip       lat       lng  ... imprecise military             timezone
# 0  601  18.18005 -66.75218  ...     False    False  America/Puerto_Rico
# 1  602  18.36074 -67.17519  ...     False    False  America/Puerto_Rico
# 2  603  18.45440 -67.12201  ...     False    False  America/Puerto_Rico
# 3  606  18.16721 -66.93828  ...     False    False  America/Puerto_Rico
# 4  610  18.29032 -67.12244  ...     False    False  America/Puerto_Rico
#
# [5 rows x 18 columns]

# %%
uszip['zip'] = uszip['zip'].astype('str').str.zfill(5)

# %%
uszip['zip'].nunique()
# Out:
# 33121

# %% [markdown]
# ##### Census
# - Contains population, demographic, poverty, and employment data by tract

# %%
df = pd.read_csv('/content/acs2017_census_tract_data.csv')
print(df.shape)
df.head()
# Out:
# (74001, 37)
#       TractId    State          County  ...  SelfEmployed  FamilyWork  Unemployment
# 0  1001020100  Alabama  Autauga County  ...           4.5         0.0           4.6
# 1  1001020200  Alabama  Autauga County  ...           9.0         0.0           3.4
# 2  1001020300  Alabama  Autauga County  ...           4.8         0.7           4.7
# 3  1001020400  Alabama  Autauga County  ...           4.5         0.0           6.1
# 4  1001020500  Alabama  Autauga County  ...           4.5         0.0           2.3
#
# [5 rows x 37 columns]

# %%
df['TractId'].nunique()
# Out:
# 74001

# %% [markdown]
# ##### Tract to Zip
# - maps census tracts to zip codes

# %%
tract_zip = pd.read_excel('/content/TRACT_ZIP_122017.xlsx')

# %%
print(tract_zip.shape)
tract_zip.head()
# Out:
# (168662, 6)
#         tract    zip  res_ratio  bus_ratio  oth_ratio  tot_ratio
# 0  1001020100  36067   1.000000   1.000000       1.00   1.000000
# 1  1001020200  36008   0.028243   0.012987       0.00   0.023846
# 2  1001020200  36067   0.971757   0.987013       1.00   0.976154
# 3  1001020300  36067   1.000000   1.000000       1.00   1.000000
# 4  1001020400  36067   0.025543   0.585987       0.25   0.071038

# %%
tract_zip = tract_zip[['tract', 'zip', 'res_ratio']]

# %%
tract_zip = tract_zip.rename(columns = {'tract':'TractId'})

# %%
tract_zip['zip'].nunique()
# Out:
# 39301

# %%
tract_zip['TractId'].nunique()
# Out:
# 73584

# %% [markdown]
# ## Merge Census with Tract_Zip Data

# %%
merge = df.merge(tract_zip, on=['TractId'])

# %%
print(merge.shape)
merge.head()
# Out:
# (168385, 39)
#       TractId    State          County  ...  Unemployment    zip  res_ratio
# 0  1001020100  Alabama  Autauga County  ...           4.6  36067   1.000000
# 1  1001020200  Alabama  Autauga County  ...           3.4  36008   0.028243
# 2  1001020200  Alabama  Autauga County  ...           3.4  36067   0.971757
# 3  1001020300  Alabama  Autauga County  ...           4.7  36067   1.000000
# 4  1001020400  Alabama  Autauga County  ...           6.1  36067   0.025543
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Seeing what does not transfer over

# %%
df[(~df.TractId.isin(merge.TractId))]
# Out:
#            TractId        State  ... FamilyWork  Unemployment
# 43      1003990000      Alabama  ...        NaN           NaN
# 868     1097990000      Alabama  ...        NaN           NaN
# 1266    2105000200       Alaska  ...        0.0          12.5
# 1324    2185000100       Alaska  ...        0.0          14.2
# 1353    4001944202      Arizona  ...        0.0          28.2
# ...            ...          ...  ...        ...           ...
# 73982  72151950700  Puerto Rico  ...        0.0          17.9
# 73983  72151950800  Puerto Rico  ...        0.0          30.4
# 73984  72151950900  Puerto Rico  ...        0.0          28.7
# 73989  72151990000  Puerto Rico  ...        NaN           NaN
# 73990  72153750101  Puerto Rico  ...        0.0          20.4
#
# [624 rows x 37 columns]

# %%
tract_zip[(~tract_zip.TractId.isin(merge.TractId))]
# Out:
#             TractId    zip  res_ratio
# 543      1037030200  36080        1.0
# 2828     1115050101  35146        1.0
# 3017     1123231500  36866        1.0
# 3673     2270000100  99563        0.0
# 3674     2270000100  99620        0.0
# ...             ...    ...        ...
# 168657  78030960800    802        1.0
# 168658  78030960900    802        1.0
# 168659  78030961000    802        1.0
# 168660  78030961100    802        1.0
# 168661  78030961200    802        1.0
#
# [277 rows x 3 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### isnull().sum()

# %%
merge.isnull().sum()
# Out:
# TractId                0
# State                  0
# County                 0
# TotalPop               0
# Men                    0
# Women                  0
# Hispanic             506
# White                506
# Black                506
# Native               506
# Asian                506
# Pacific              506
# VotingAgeCitizen       0
# Income              1291
# IncomeErr           1291
# IncomePerCap         596
# IncomePerCapErr      596
# Poverty              710
# ChildPoverty        1286
# Professional         652
# Service              652
# Office               652
# Construction         652
# Production           652
# Drive                633
# Carpool              633
# Transit              633
# Walk                 633
# OtherTransp          633
# WorkAtHome           633
# MeanCommute          949
# Employed               0
# PrivateWork          652
# PublicWork           652
# SelfEmployed         652
# FamilyWork           652
# Unemployment         650
# zip                    0
# res_ratio              0
# dtype: int64

# %% [markdown]
# ### Fill na with 0

# %%
merge.fillna(0, inplace=True)

# %%
merge.isnull().sum()
# Out:
# TractId             0
# State               0
# County              0
# TotalPop            0
# Men                 0
# Women               0
# Hispanic            0
# White               0
# Black               0
# Native              0
# Asian               0
# Pacific             0
# VotingAgeCitizen    0
# Income              0
# IncomeErr           0
# IncomePerCap        0
# IncomePerCapErr     0
# Poverty             0
# ChildPoverty        0
# Professional        0
# Service             0
# Office              0
# Construction        0
# Production          0
# Drive               0
# Carpool             0
# Transit             0
# Walk                0
# OtherTransp         0
# WorkAtHome          0
# MeanCommute         0
# Employed            0
# PrivateWork         0
# PublicWork          0
# SelfEmployed        0
# FamilyWork          0
# Unemployment        0
# zip                 0
# res_ratio           0
# dtype: int64

# %%
merge.State.unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'Puerto Rico'],
#       dtype=object)

# %% [markdown]
# ### Remove nonstates

# %%
# Remove areas we don't have in other df
merge = merge[merge['State'] != 'District of Columbia']
merge = merge[merge['State'] != 'Puerto Rico']

# %%
merge['State'].nunique()
# Out:
# 50

# %% [markdown]
# ## Map Tracts to Zip Code
# * first get multiply % columns by total population
# * multiply % columns by employed
# * multiply residential ratio across rows

# %% [markdown]
# ### Make Numbers Compatible

# %% [markdown]
# #### Dividing certain columns by 100

# %% [markdown]
# ##### Making sure I capture the correct columns

# %%
merge.iloc[:,6:11+1]
# Out:
#         Hispanic  White  Black  Native  Asian  Pacific
# 0            2.4   86.3    5.2     0.0    1.2      0.0
# 1            1.1   41.6   54.5     0.0    1.0      0.0
# 2            1.1   41.6   54.5     0.0    1.0      0.0
# 3            8.0   61.4   26.5     0.6    0.7      0.4
# 4            9.6   80.3    7.1     0.5    0.2      0.0
# ...          ...    ...    ...     ...    ...      ...
# 166947       3.0   89.4    1.0     0.1    3.0      0.0
# 166948       3.0   89.4    1.0     0.1    3.0      0.0
# 166949       3.0   89.4    1.0     0.1    3.0      0.0
# 166950       3.0   89.4    1.0     0.1    3.0      0.0
# 166951       0.1   93.6    0.0     0.1    5.4      0.0
#
# [166434 rows x 6 columns]

# %%
merge.iloc[:,17:30+1]
# Out:
#         Poverty  ChildPoverty  ...  WorkAtHome  MeanCommute
# 0          10.7          20.8  ...         2.1         24.5
# 1          22.4          35.8  ...         0.0         22.2
# 2          22.4          35.8  ...         0.0         22.2
# 3          14.7          21.1  ...         1.5         23.1
# 4           2.3           1.7  ...         2.1         25.9
# ...         ...           ...  ...         ...          ...
# 166947     12.5          18.5  ...         5.2         31.3
# 166948     12.5          18.5  ...         5.2         31.3
# 166949     12.5          18.5  ...         5.2         31.3
# 166950     12.5          18.5  ...         5.2         31.3
# 166951     15.9          27.7  ...         8.3         20.7
#
# [166434 rows x 14 columns]

# %%
merge.iloc[:,32:36+1]
# Out:
#         PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0              74.2        21.2           4.5         0.0           4.6
# 1              75.9        15.0           9.0         0.0           3.4
# 2              75.9        15.0           9.0         0.0           3.4
# 3              73.3        21.1           4.8         0.7           4.7
# 4              75.8        19.7           4.5         0.0           6.1
# ...             ...         ...           ...         ...           ...
# 166947         64.6        22.9          10.9         1.6           0.4
# 166948         64.6        22.9          10.9         1.6           0.4
# 166949         64.6        22.9          10.9         1.6           0.4
# 166950         64.6        22.9          10.9         1.6           0.4
# 166951         71.3        21.1           7.0         0.6           3.7
#
# [166434 rows x 5 columns]

# %%
merge.iloc[:,6:11+1] /= 100

# %%
merge.iloc[:,17:30+1] /= 100

# %%
merge.iloc[:,32:36+1] /= 100

# %%
merge.head()
# Out:
#       TractId    State          County  ...  Unemployment    zip  res_ratio
# 0  1001020100  Alabama  Autauga County  ...         0.046  36067   1.000000
# 1  1001020200  Alabama  Autauga County  ...         0.034  36008   0.028243
# 2  1001020200  Alabama  Autauga County  ...         0.034  36067   0.971757
# 3  1001020300  Alabama  Autauga County  ...         0.047  36067   1.000000
# 4  1001020400  Alabama  Autauga County  ...         0.061  36067   0.025543
#
# [5 rows x 39 columns]

# %% [markdown]
# ##### Multiply Columns by Total Population

# %%
merge.columns
# Out:
# Index(['TractId', 'State', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic',
#        'White', 'Black', 'Native', 'Asian', 'Pacific', 'VotingAgeCitizen',
#        'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment', 'zip', 'res_ratio'],
#       dtype='object')

# %%
col = ['Hispanic','White', 'Black', 'Native', 'Asian', 'Pacific','Poverty',
       'ChildPoverty','Unemployment']

# %%
merge[col] = merge[col].multiply(merge['TotalPop'], axis = 'index')

# %%
merge[col] = merge[col].astype(int)

# %% [markdown]
# ### Multiply

# %%
employment = ['Professional', 'Service', 'Office', 'Construction', 'Production', 
              'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 
              'MeanCommute','PrivateWork', 'PublicWork','SelfEmployed', 'FamilyWork']

# %%
merge[employment] = merge[employment].multiply(merge['Employed'], axis = 'index')

# %%
merge[employment] = merge[employment].astype(int)

# %% [markdown]
# ##### Check values

# %%
df.loc[
       (df.State == 'Wyoming')
       &(df.TotalPop == 3329)
       &(df.TractId == 56045951100)]
# Out:
#            TractId    State  ... FamilyWork  Unemployment
# 73054  56045951100  Wyoming  ...        1.6           0.4
#
# [1 rows x 37 columns]

# %%
merge.loc[166948:166948]
# Out:
#             TractId    State         County  ...  Unemployment    zip  res_ratio
# 166948  56045951100  Wyoming  Weston County  ...            13  82729   0.002424
#
# [1 rows x 39 columns]

# %%
int(3/100 * 3329)
# Out:
# 99

# %%
int(89.4/100 * 3329)
# Out:
# 2976

# %%
int(64.6/100  * 1583)
# Out:
# 1022

# %%
int(1.6/100  * 1583)
# Out:
# 25

# %%
assert merge['Hispanic'][166948] == 99

# %%
assert merge['White'][166948] == 2976

# %%
assert merge['PrivateWork'][166948] == 1022

# %%
assert merge['FamilyWork'][166948] == 25

# %%
df.loc[
       (df.State == 'Alabama')
       &(df.TotalPop == 7131)
       &(df.TractId == 1003011601)]
# Out:
#        TractId    State          County  ...  SelfEmployed  FamilyWork  Unemployment
# 41  1003011601  Alabama  Baldwin County  ...          13.5         0.2           3.1
#
# [1 rows x 37 columns]

# %%
merge.loc[105:105]
# Out:
#         TractId    State          County  ...  Unemployment    zip  res_ratio
# 105  1003011601  Alabama  Baldwin County  ...           221  36580    0.01071
#
# [1 rows x 39 columns]

# %%
int(9.7/100 * 7131)
# Out:
# 691

# %%
int(25.4/100 * 3260)
# Out:
# 828

# %%
int(11.3/100 * 3260)
# Out:
# 368

# %%
int(9.5/100 * 3260)
# Out:
# 309

# %%
int(13.5/100 * 3260)
# Out:
# 440

# %%
assert merge['Hispanic'][105] == 691

# %%
assert merge['Professional'][105] == 828

# %%
assert merge['Construction'][105] == 368

# %%
assert merge['PublicWork'][105] == 309

# %%
assert merge['SelfEmployed'][105] == 440

# %% [markdown]
# #### Mutiply each row by residential ratio

# %%
newcol = ['TotalPop', 'Men', 'Women', 'Hispanic',
       'White', 'Black', 'Native', 'Asian', 'Pacific', 'VotingAgeCitizen',
       'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
       'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
       'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
       'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
       'SelfEmployed', 'FamilyWork', 'Unemployment']

# %%
merge[newcol] = merge[newcol].multiply(merge['res_ratio'], axis = 'index')

# %%
merge[newcol] = merge[newcol].astype(int)

# %%
merge.head(15)
# Out:
#        TractId    State          County  ...  Unemployment    zip  res_ratio
# 0   1001020100  Alabama  Autauga County  ...            84  36067   1.000000
# 1   1001020200  Alabama  Autauga County  ...             2  36008   0.028243
# 2   1001020200  Alabama  Autauga County  ...            70  36067   0.971757
# 3   1001020300  Alabama  Autauga County  ...           159  36067   1.000000
# 4   1001020400  Alabama  Autauga County  ...             6  36067   0.025543
# 5   1001020400  Alabama  Autauga County  ...           253  36066   0.974457
# 6   1001020500  Alabama  Autauga County  ...           180  36066   0.788390
# 7   1001020500  Alabama  Autauga County  ...            48  36068   0.210806
# 8   1001020500  Alabama  Autauga County  ...             0  36067   0.000804
# 9   1001020600  Alabama  Autauga County  ...           220  36067   1.000000
# 10  1001020700  Alabama  Autauga County  ...           577  36067   1.000000
# 11  1001020801  Alabama  Autauga County  ...           209  36067   1.000000
# 12  1001020802  Alabama  Autauga County  ...            48  36022   0.194991
# 13  1001020802  Alabama  Autauga County  ...           141  36067   0.566622
# 14  1001020802  Alabama  Autauga County  ...            59  36066   0.238387
#
# [15 rows x 39 columns]

# %%
min(merge['zip']), max(merge['zip'])
# Out:
# (501, 99929)

# %%
merge['zip'] = merge['zip'].astype('str').str.zfill(5)

# %%
merge = merge.drop(columns = ['res_ratio'])

# %% [markdown]
# ## Ratios
# -return df back to census form

# %% [markdown]
# ##### Multiply columns by 100

# %%
merge.iloc[:,6:11+1] *= 100

# %%
merge.iloc[:,17:30+1] *= 100

# %%
merge.iloc[:,32:36+1] *= 100

# %%
col = ['Hispanic','White', 'Black', 'Native', 'Asian', 'Pacific','Poverty',
       'ChildPoverty','Unemployment']

# %% [markdown]
# ##### Divide columns by Total Population

# %%
merge[col] = merge[col].divide(merge['TotalPop'], axis = 'index')

# %%
merge[col] = merge[col].round(1)

# %% [markdown]
# ##### Divide columns by Employed

# %%
employment = ['Professional', 'Service', 'Office', 'Construction', 'Production', 
              'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 
              'MeanCommute', 'PrivateWork', 'PublicWork','SelfEmployed', 'FamilyWork']

# %%
merge[employment] = merge[employment].divide(merge['Employed'], axis = 'index')

# %%
merge[employment] = merge[employment].round(1)

# %% [markdown]
# ##### Check

# %%
merge.head()
# Out:
#       TractId    State          County  ...  FamilyWork  Unemployment    zip
# 0  1001020100  Alabama  Autauga County  ...         0.0           4.6  36067
# 1  1001020200  Alabama  Autauga County  ...         0.0           3.3  36008
# 2  1001020200  Alabama  Autauga County  ...         0.0           3.3  36067
# 3  1001020300  Alabama  Autauga County  ...         0.7           4.7  36067
# 4  1001020400  Alabama  Autauga County  ...         0.0           5.6  36067
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Map Zip Codes to City

# %%
uszip.columns
# Out:
# Index(['zip', 'lat', 'lng', 'city', 'state_id', 'state_name', 'zcta',
#        'parent_zcta', 'population', 'density', 'county_fips', 'county_name',
#        'county_weights', 'county_names_all', 'county_fips_all', 'imprecise',
#        'military', 'timezone'],
#       dtype='object')

# %%
uszip = uszip[['zip', 'city', 'state_name', 'state_id', 'county_name']]

# %%
merge = merge.merge(uszip, on = 'zip')

# %%
merge.shape
# Out:
# (159684, 42)

# %%
merge.head()
# Out:
#       TractId    State          County  ...  state_name  state_id  county_name
# 0  1001020100  Alabama  Autauga County  ...     Alabama        AL      Autauga
# 1  1001020200  Alabama  Autauga County  ...     Alabama        AL      Autauga
# 2  1001020300  Alabama  Autauga County  ...     Alabama        AL      Autauga
# 3  1001020400  Alabama  Autauga County  ...     Alabama        AL      Autauga
# 4  1001020500  Alabama  Autauga County  ...     Alabama        AL      Autauga
#
# [5 rows x 42 columns]

# %%
merge.columns
# Out:
# Index(['TractId', 'State', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic',
#        'White', 'Black', 'Native', 'Asian', 'Pacific', 'VotingAgeCitizen',
#        'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment', 'zip', 'city',
#        'state_name', 'state_id', 'county_name'],
#       dtype='object')

# %%
columns = ['TractId', 'city', 'state_id', 'State', 'County', 'county_name', 
           'TotalPop', 'Men', 'Women', 'Hispanic','White', 'Black', 'Native', 
           'Asian', 'Pacific', 'VotingAgeCitizen','Income', 'IncomeErr', 
           'IncomePerCap', 'IncomePerCapErr', 'Poverty', 'ChildPoverty', 
           'Professional', 'Service', 'Office', 'Construction', 'Production', 
           'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 
           'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 
           'SelfEmployed', 'FamilyWork', 'Unemployment', 'zip', ]

# %%
merge = merge[columns]

# %%
merge.head()
# Out:
#       TractId        city state_id  ... FamilyWork Unemployment    zip
# 0  1001020100  Prattville       AL  ...        0.0          4.6  36067
# 1  1001020200  Prattville       AL  ...        0.0          3.3  36067
# 2  1001020300  Prattville       AL  ...        0.7          4.7  36067
# 3  1001020400  Prattville       AL  ...        0.0          5.6  36067
# 4  1001020500  Prattville       AL  ...        0.0          0.0  36067
#
# [5 rows x 41 columns]

# %% [markdown]
# ### Create clean copy

# %%
merge.isnull().sum()
# Out:
# TractId                 0
# city                    0
# state_id                0
# State                   0
# County                  0
# county_name             0
# TotalPop                0
# Men                     0
# Women                   0
# Hispanic             8736
# White                8736
# Black                8736
# Native               8736
# Asian                8736
# Pacific              8736
# VotingAgeCitizen        0
# Income                  0
# IncomeErr               0
# IncomePerCap            0
# IncomePerCapErr         0
# Poverty              8736
# ChildPoverty         8736
# Professional        10607
# Service             10607
# Office              10607
# Construction        10607
# Production          10607
# Drive               10607
# Carpool             10607
# Transit             10607
# Walk                10607
# OtherTransp         10607
# WorkAtHome          10607
# MeanCommute         10607
# Employed                0
# PrivateWork         10607
# PublicWork          10607
# SelfEmployed        10607
# FamilyWork          10607
# Unemployment         8736
# zip                     0
# dtype: int64

# %%
merge = merge.dropna(axis=0, subset = ['Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific'], how = 'all')
merge = merge.dropna(axis=0, subset = ['Professional', 'Service', 'Office', 'Construction', 
                                       'Production','Drive', 'Carpool', 'Transit', 'Walk', 
                                       'OtherTransp', 'WorkAtHome', 'MeanCommute'], how = 'all')
merge = merge.replace(np.nan, 0)

# %%
merge.shape
# Out:
# (149077, 41)

# %%
merge.to_csv('merge.csv')

# %%
# !cp merge.csv "drive/My Drive/"

# %% [markdown]
# ##  CSVs - Group by Cities

# %%
merge = merge.rename(columns = {'city': 'City',
                                'state_id':'State_Id'})

# %% [markdown]
# ### Diversity

# %%
total_pop_df = merge[['TotalPop', 'Men', 'Women','City', 'State_Id']].groupby(['City', 'State_Id'],as_index=False).sum()
total_pop_df.head()
# Out:
#          City State_Id  TotalPop    Men  Women
# 0  Aaronsburg       PA      1056    532    524
# 1   Abbeville       AL      6693   3361   3329
# 2   Abbeville       GA      4683   3205   1478
# 3   Abbeville       LA     25185  12341  12839
# 4   Abbeville       MS      2078   1033   1042

# %%
diversity_df = merge[['Hispanic','White', 'Black', 'Native', 'Asian', 'Pacific', 'City', 'State_Id']].groupby(['City', 'State_Id'],as_index=False).mean()
diversity_df[['Hispanic','White', 'Black', 'Native', 'Asian', 'Pacific']] = diversity_df[['Hispanic','White', 'Black', 'Native', 'Asian', 'Pacific']].round(1)
diversity_df.head()
# Out:
#          City State_Id  Hispanic  White  Black  Native  Asian  Pacific
# 0  Aaronsburg       PA       1.0   97.4    0.0     0.0    0.7      0.0
# 1   Abbeville       AL       3.6   64.2   31.4     0.0    0.0      0.0
# 2   Abbeville       GA       2.7   58.7   37.1     0.4    0.0      0.0
# 3   Abbeville       LA       3.9   77.0   14.2     0.3    2.1      0.0
# 4   Abbeville       MS       4.7   60.9   31.3     0.0    0.8      0.0

# %%
diversity_df = total_pop_df.merge(diversity_df, on = ['City', 'State_Id'])
diversity_df.head()
# Out:
#          City State_Id  TotalPop    Men  ...  Black  Native  Asian  Pacific
# 0  Aaronsburg       PA      1056    532  ...    0.0     0.0    0.7      0.0
# 1   Abbeville       AL      6693   3361  ...   31.4     0.0    0.0      0.0
# 2   Abbeville       GA      4683   3205  ...   37.1     0.4    0.0      0.0
# 3   Abbeville       LA     25185  12341  ...   14.2     0.3    2.1      0.0
# 4   Abbeville       MS      2078   1033  ...   31.3     0.0    0.8      0.0
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Income Per Capita

# %%
income_per_capita_df = merge[['Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr','City', 'State_Id']].groupby(['City', 'State_Id'],as_index=False).mean()
income_per_capita_df[['Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr']] = income_per_capita_df[['Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr']].round(1)
income_per_capita_df.to_csv("income_per_capita_df.csv",index=False)
income_per_capita_df.head()
# Out:
#          City State_Id   Income  IncomeErr  IncomePerCap  IncomePerCapErr
# 0  Aaronsburg       PA  10258.0     1258.0        4516.0            324.0
# 1   Abbeville       AL  27895.8     6168.8       15016.5           2161.2
# 2   Abbeville       GA  14165.7     3522.0        5631.3           1339.0
# 3   Abbeville       LA  26087.2     5041.7       12330.7           1597.9
# 4   Abbeville       MS   7885.3     1314.7        4145.0            634.3

# %% [markdown]
# ### Poverty

# %%
poverty_df = merge[['Poverty', 'ChildPoverty','City', 'State_Id']].groupby(['City', 'State_Id'],as_index=False).sum()
poverty_df.to_csv("poverty_df.csv",index=False)
poverty_df.head()
# Out:
#          City State_Id  Poverty  ChildPoverty
# 0  Aaronsburg       PA     16.4          31.6
# 1   Abbeville       AL     71.5         126.0
# 2   Abbeville       GA     75.2         100.5
# 3   Abbeville       LA    201.7         251.2
# 4   Abbeville       MS     58.8          87.8

# %% [markdown]
# ### Industries

# %%
industry_df = merge[['Professional', 'Service', 'Office', 'Construction', 'Production','City', 'State_Id']].groupby(['City', 'State_Id'],as_index=False).sum()
industry_df.to_csv("industry_df.csv",index=False)
industry_df.head()
# Out:
#          City State_Id  Professional  Service  Office  Construction  Production
# 0  Aaronsburg       PA          27.5     21.1    18.9          15.5        16.5
# 1   Abbeville       AL         109.5     72.2    76.2          39.3        99.5
# 2   Abbeville       GA          86.0     75.6    42.3          41.6        48.6
# 3   Abbeville       LA         277.0    169.7   266.4         188.8       135.9
# 4   Abbeville       MS         107.1     62.7    44.1          24.6        52.3

# %% [markdown]
# ### Transportation

# %%
transportation_df = merge[['Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute','City', 'State_Id']].groupby(['City', 'State_Id'],as_index=False).mean()
transportation_df[['Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute',]] = transportation_df[['Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute']].round(1)
transportation_df.to_csv("transportation_df.csv",index=False)
transportation_df.head()
# Out:
#          City State_Id  Drive  ...  OtherTransp  WorkAtHome  MeanCommute
# 0  Aaronsburg       PA   69.5  ...          3.6        10.2         27.7
# 1   Abbeville       AL   85.0  ...          1.6         2.4         26.7
# 2   Abbeville       GA   86.2  ...          0.9         2.9         26.8
# 3   Abbeville       LA   80.1  ...          1.5         2.8         29.1
# 4   Abbeville       MS   83.4  ...          0.0         1.5         25.0
#
# [5 rows x 9 columns]

# %% [markdown]
# ### Employment

# %%
employment_df = merge[['Employed', 'Unemployment','City', 'State_Id']].groupby(['City', 'State_Id'],as_index=False).sum()
employment_df.to_csv('employment_df.csv', index=False)
employment_df.head()
# Out:
#          City State_Id  Employed  Unemployment
# 0  Aaronsburg       PA       502           3.1
# 1   Abbeville       AL      2485          31.0
# 2   Abbeville       GA       824          18.0
# 3   Abbeville       LA     10437          76.5
# 4   Abbeville       MS       887          17.3

# %% [markdown]
# ### Employment Type

# %%
employment_ratio_df = merge[['PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork','City', 'State_Id']].groupby(['City', 'State_Id'],as_index=False).mean()
employment_ratio_df[['PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork']] = employment_ratio_df[['PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork']].round(1)
employment_ratio_df.to_csv('employment_ratio_df.csv', index=False)
employment_ratio_df.head()
# Out:
#          City State_Id  PrivateWork  PublicWork  SelfEmployed  FamilyWork
# 0  Aaronsburg       PA         76.5        10.8          12.4         0.0
# 1   Abbeville       AL         79.5        14.7           5.2         0.0
# 2   Abbeville       GA         59.3        30.3           9.5         0.0
# 3   Abbeville       LA         81.2        11.5           5.2         0.0
# 4   Abbeville       MS         71.7        20.5           6.7         0.0

# %% [markdown]
# Total_DF

# %%
census_df = diversity_df.merge(income_per_capita_df, on=['City', 'State_Id'])
census_df = census_df.merge(poverty_df, on=['City', 'State_Id'])
census_df = census_df.merge(employment_df, on=['City', 'State_Id'])
census_df = census_df.merge(employment_ratio_df, on=['City', 'State_Id'])
census_df = census_df.merge(industry_df, on=['City', 'State_Id'])
census_df = census_df.merge(transportation_df, on=['City', 'State_Id'])

# %%
census_df.head()
# Out:
#          City State_Id  TotalPop  ...  OtherTransp  WorkAtHome  MeanCommute
# 0  Aaronsburg       PA      1056  ...          3.6        10.2         27.7
# 1   Abbeville       AL      6693  ...          1.6         2.4         26.7
# 2   Abbeville       GA      4683  ...          0.9         2.9         26.8
# 3   Abbeville       LA     25185  ...          1.5         2.8         29.1
# 4   Abbeville       MS      2078  ...          0.0         1.5         25.0
#
# [5 rows x 35 columns]

# %%
census_df.to_csv('census_by_city.csv', index=False)
