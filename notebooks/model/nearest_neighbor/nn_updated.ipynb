# %% [markdown]
# ### LOAD DIVERSITY CSV
# most updated csv

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
merged = pd.read_csv('diversity.csv')

# %%
merged.head()
# Out:
#           City State      lat       lon  TotalPop     Men   Women  Hispanic  \
# 0        Akron    OH  41.0798  -81.5219    267782  129623  138086       1.9
# 1       Albany    GA  31.5776  -84.1762     93421   43571   49835       2.8
# 2       Albany    NY  42.6664  -73.7987    147794   70664   77096       7.8
# 3       Albany    OR  44.6274 -123.0966     61555   30378   31168      11.4
# 4  Albuquerque    NM  35.1053 -106.6464    632240  309415  322758      50.4
#
#    White  Black  Native  Asian  Pacific   Income  IncomeErr  IncomePerCap  \
# 0   67.4   23.2     0.2    3.6      0.0  3068406     504125       1732548
# 1   29.2   65.2     0.1    0.9      0.0  1025141     199233        547674
# 2   60.3   20.1     0.1    7.6      0.0  1917135     331452       1102265
# 3   82.7    0.6     0.7    1.9      0.1   542299      75753        268177
# 4   38.5    2.5     4.0    2.4      0.1  7693803    1270581       4099669
#
#    IncomePerCapErr  Poverty  ChildPoverty  Employed  Unemployment  \
# 0           258991     19.6          26.2    126247           8.5
# 1            89500     29.6          41.9     35704          16.2
# 2           158632     17.4          17.8     74293           6.6
# 3            35254     14.3          18.6     27721           8.2
# 4           581026     18.2          24.8    292907           6.8
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Professional  Service  \
# 0         85.4        10.3           4.1         0.1          32.3     19.8
# 1         71.9        23.7           4.1         0.1          30.7     21.4
# 2         71.6        24.3           3.9         0.0          42.9     20.5
# 3         78.5        15.9           5.4         0.1          33.3     18.4
# 4         74.5        19.6           5.6         0.2          39.8     20.0
#
#    Office  Construction  Production  Drive  Carpool  Transit  Walk  \
# 0    25.3           6.6        15.6   83.3      8.5      3.1   1.6
# 1    23.1           8.1        16.3   78.1     12.4      1.8   2.3
# 2    25.2           4.6         6.6   70.4      7.2     10.1   7.3
# 3    22.7           9.9        15.5   79.0     10.7      0.3   2.6
# 4    24.0           8.3         7.7   80.2      9.1      1.8   1.8
#
#    OtherTransp  WorkAtHome  MeanCommute  Rent  Year  Population  \
# 0          0.6         2.7         21.9   911  2020      197882
# 1          0.7         4.3         19.1   814  2020       74989
# 2          1.7         2.9         18.9  1205  2020       97221
# 3          2.0         5.1         20.8  1197  2020       54993
# 4          2.5         4.3         21.7  1013  2020      561920
#
#    Violent crime  Murder and nonnegligent manslaughter  Rape  Robbery  \
# 0           1782                                    27   181      328
# 1            790                                    12    32      165
# 2            736                                     4    60      189
# 3             70                                     1    10       16
# 4           7596                                    84   486     1699
#
#    Aggravated assault  Property crime  Burglary  Larceny- theft  \
# 0                1246            6568      1686            4305
# 1                 581            3452       729            2489
# 2                 483            2919       445            2315
# 3                  43            1467       128            1242
# 4                5327           26059         0           20634
#
#    Motor vehicle theft  Arson  Crime Rate per 1000 Crime Rating  \
# 0                  577     65                42.20         High
# 1                  234     17                56.57         High
# 2                  159     16                37.59       Medium
# 3                   97     17                27.95       Medium
# 4                 5425     98                59.89         High
#
#    Days with AQI  Good Days  Moderate Days  \
# 0            274        203             68
# 1            244        182             60
# 2            274        240             34
# 3            182        161             21
# 4            183        101             82
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    3               0                    0
# 1                                    2               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0               0      107                   63          43        0
# 1               0      114                   63          37        0
# 2               0       75                   53          39        1
# 3               0       70                   51          19        0
# 4               0      100                   65          50        1
#
#    Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10 Air Quality Index  \
# 0         0         132         0         142          0              Good
# 1         0           0         0         244          0              Good
# 2         0         169         0         104          0              Good
# 3         0           0         0         182          0              Good
# 4         0         127         0          25         30              Good
#
#    Diversity Index
# 0         0.490241
# 1         0.488771
# 2         0.584133
# 3         0.302632
# 4         0.594958

# %% [markdown]
# ### NEAREST NEIGHBORS

# %%
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %%
merged.columns
# Out:
# Index(['City', 'State', 'lat', 'lon', 'TotalPop', 'Men', 'Women', 'Hispanic',
#        'White', 'Black', 'Native', 'Asian', 'Pacific', 'Income', 'IncomeErr',
#        'IncomePerCap', 'IncomePerCapErr', 'Poverty', 'ChildPoverty',
#        'Employed', 'Unemployment', 'PrivateWork', 'PublicWork', 'SelfEmployed',
#        'FamilyWork', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Rent', 'Year', 'Population',
#        'Violent crime', 'Murder and nonnegligent manslaughter', 'Rape',
#        'Robbery', 'Aggravated assault', 'Property crime', 'Burglary',
#        'Larceny- theft', 'Motor vehicle theft', 'Arson', 'Crime Rate per 1000',
#        'Crime Rating', 'Days with AQI', 'Good Days', 'Moderate Days',
#        'Unhealthy for Sensitive Groups Days', 'Unhealthy Days',
#        'Very Unhealthy Days', 'Hazardous Days', 'Max AQI',
#        '90th Percentile AQI', 'Median AQI', 'Days CO', 'Days NO2',
#        'Days Ozone', 'Days SO2', 'Days PM2.5', 'Days PM10',
#        'Air Quality Index', 'Diversity Index'],
#       dtype='object')

# %%
X = merged[[
       'TotalPop', 'Men', 'Women', 'Hispanic', 'White',
       'Black', 'Native', 'Asian', 'Pacific', 'Diversity Index',
       'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 
       'Poverty', 'ChildPoverty',
       'Employed', 'Unemployment', 
       'PrivateWork', 'PublicWork', 'SelfEmployed','FamilyWork', 
       'Professional', 'Service', 'Office', 'Construction','Production', 
       'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 
       'Violent crime', 'Murder and nonnegligent manslaughter', 'Rape',
       'Robbery', 'Aggravated assault', 'Property crime', 'Burglary',
       'Larceny- theft', 'Motor vehicle theft', 'Arson', 'Crime Rate per 1000',
       'Rent',
       'Days with AQI','Good Days', 'Moderate Days', 
       'Unhealthy for Sensitive Groups Days',
       'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days', 
       'Max AQI', '90th Percentile AQI', 'Median AQI', 'Days CO', 
       'Days NO2','Days Ozone', 'Days SO2', 'Days PM2.5', 'Days PM10'
       ]]

# %% [markdown]
# ## Nearest Neighbors

# %%
# scaling data since the values are not the same, i.e 1000s for rent and populutaion versus numbers shown as percentages
scaler = StandardScaler() 
standard_df = scaler.fit_transform(X) 
standard_df = pd.DataFrame(standard_df, columns = X.columns)

# %%
nn = NearestNeighbors(n_neighbors=6, algorithm='kd_tree', n_jobs=8)
nn.fit(standard_df)
# Out:
# NearestNeighbors(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#                  metric_params=None, n_jobs=8, n_neighbors=6, p=2, radius=1.0)

# %%
def nearest(idx):
    return ','.join(map(str, nn.kneighbors([standard_df.iloc[idx]])[1][0][1:].tolist()))

# %%
merged['Index'] = merged.index

# %%
merged['Nearest'] = merged['Index'].apply(nearest)

# %% [markdown]
# ### TEST

# %%
merged.head()
# Out:
#           City State      lat       lon  TotalPop     Men   Women  Hispanic  \
# 0        Akron    OH  41.0798  -81.5219    267782  129623  138086       1.9
# 1       Albany    GA  31.5776  -84.1762     93421   43571   49835       2.8
# 2       Albany    NY  42.6664  -73.7987    147794   70664   77096       7.8
# 3       Albany    OR  44.6274 -123.0966     61555   30378   31168      11.4
# 4  Albuquerque    NM  35.1053 -106.6464    632240  309415  322758      50.4
#
#    White  Black  Native  Asian  Pacific   Income  IncomeErr  IncomePerCap  \
# 0   67.4   23.2     0.2    3.6      0.0  3068406     504125       1732548
# 1   29.2   65.2     0.1    0.9      0.0  1025141     199233        547674
# 2   60.3   20.1     0.1    7.6      0.0  1917135     331452       1102265
# 3   82.7    0.6     0.7    1.9      0.1   542299      75753        268177
# 4   38.5    2.5     4.0    2.4      0.1  7693803    1270581       4099669
#
#    IncomePerCapErr  Poverty  ChildPoverty  Employed  Unemployment  \
# 0           258991     19.6          26.2    126247           8.5
# 1            89500     29.6          41.9     35704          16.2
# 2           158632     17.4          17.8     74293           6.6
# 3            35254     14.3          18.6     27721           8.2
# 4           581026     18.2          24.8    292907           6.8
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Professional  Service  \
# 0         85.4        10.3           4.1         0.1          32.3     19.8
# 1         71.9        23.7           4.1         0.1          30.7     21.4
# 2         71.6        24.3           3.9         0.0          42.9     20.5
# 3         78.5        15.9           5.4         0.1          33.3     18.4
# 4         74.5        19.6           5.6         0.2          39.8     20.0
#
#    Office  Construction  Production  Drive  Carpool  Transit  Walk  \
# 0    25.3           6.6        15.6   83.3      8.5      3.1   1.6
# 1    23.1           8.1        16.3   78.1     12.4      1.8   2.3
# 2    25.2           4.6         6.6   70.4      7.2     10.1   7.3
# 3    22.7           9.9        15.5   79.0     10.7      0.3   2.6
# 4    24.0           8.3         7.7   80.2      9.1      1.8   1.8
#
#    OtherTransp  WorkAtHome  MeanCommute  Rent  Year  Population  \
# 0          0.6         2.7         21.9   911  2020      197882
# 1          0.7         4.3         19.1   814  2020       74989
# 2          1.7         2.9         18.9  1205  2020       97221
# 3          2.0         5.1         20.8  1197  2020       54993
# 4          2.5         4.3         21.7  1013  2020      561920
#
#    Violent crime  Murder and nonnegligent manslaughter  Rape  Robbery  \
# 0           1782                                    27   181      328
# 1            790                                    12    32      165
# 2            736                                     4    60      189
# 3             70                                     1    10       16
# 4           7596                                    84   486     1699
#
#    Aggravated assault  Property crime  Burglary  Larceny- theft  \
# 0                1246            6568      1686            4305
# 1                 581            3452       729            2489
# 2                 483            2919       445            2315
# 3                  43            1467       128            1242
# 4                5327           26059         0           20634
#
#    Motor vehicle theft  Arson  Crime Rate per 1000 Crime Rating  \
# 0                  577     65                42.20         High
# 1                  234     17                56.57         High
# 2                  159     16                37.59       Medium
# 3                   97     17                27.95       Medium
# 4                 5425     98                59.89         High
#
#    Days with AQI  Good Days  Moderate Days  \
# 0            274        203             68
# 1            244        182             60
# 2            274        240             34
# 3            182        161             21
# 4            183        101             82
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    3               0                    0
# 1                                    2               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0               0      107                   63          43        0
# 1               0      114                   63          37        0
# 2               0       75                   53          39        1
# 3               0       70                   51          19        0
# 4               0      100                   65          50        1
#
#    Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10 Air Quality Index  \
# 0         0         132         0         142          0              Good
# 1         0           0         0         244          0              Good
# 2         0         169         0         104          0              Good
# 3         0           0         0         182          0              Good
# 4         0         127         0          25         30              Good
#
#    Diversity Index  Index              Nearest
# 0         0.490241      0   126,56,332,355,295
# 1         0.488771      1  162,372,139,351,249
# 2         0.584133      2   319,358,336,145,79
# 3         0.302632      3   29,132,230,383,202
# 4         0.594958      4  359,258,386,360,127

# %%
merged[0:1]
# Out:
#     City State      lat      lon  TotalPop     Men   Women  Hispanic  White  \
# 0  Akron    OH  41.0798 -81.5219    267782  129623  138086       1.9   67.4
#
#    Black  Native  Asian  Pacific   Income  IncomeErr  IncomePerCap  \
# 0   23.2     0.2    3.6      0.0  3068406     504125       1732548
#
#    IncomePerCapErr  Poverty  ChildPoverty  Employed  Unemployment  \
# 0           258991     19.6          26.2    126247           8.5
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Professional  Service  \
# 0         85.4        10.3           4.1         0.1          32.3     19.8
#
#    Office  Construction  Production  Drive  Carpool  Transit  Walk  \
# 0    25.3           6.6        15.6   83.3      8.5      3.1   1.6
#
#    OtherTransp  WorkAtHome  MeanCommute  Rent  Year  Population  \
# 0          0.6         2.7         21.9   911  2020      197882
#
#    Violent crime  Murder and nonnegligent manslaughter  Rape  Robbery  \
# 0           1782                                    27   181      328
#
#    Aggravated assault  Property crime  Burglary  Larceny- theft  \
# 0                1246            6568      1686            4305
#
#    Motor vehicle theft  Arson  Crime Rate per 1000 Crime Rating  \
# 0                  577     65                 42.2         High
#
#    Days with AQI  Good Days  Moderate Days  \
# 0            274        203             68
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    3               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0               0      107                   63          43        0
#
#    Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10 Air Quality Index  \
# 0         0         132         0         142          0              Good
#
#    Diversity Index  Index             Nearest
# 0         0.490241      0  126,56,332,355,295

# %%
merged[126:127]
# Out:
#            City State      lat      lon  TotalPop     Men   Women  Hispanic  \
# 126  Fort Wayne    IN  41.0886 -85.1437    310297  150404  159837       7.9
#
#      White  Black  Native  Asian  Pacific   Income  IncomeErr  IncomePerCap  \
# 126   71.4   12.8     0.1    4.0      0.0  3895090     609055       1984433
#
#      IncomePerCapErr  Poverty  ChildPoverty  Employed  Unemployment  \
# 126           288140     16.0          22.0    148626           6.9
#
#      PrivateWork  PublicWork  SelfEmployed  FamilyWork  Professional  Service  \
# 126         87.5         8.4           3.9         0.1          33.9     16.7
#
#      Office  Construction  Production  Drive  Carpool  Transit  Walk  \
# 126    24.5           6.9        17.6   84.4      8.8      0.9   1.1
#
#      OtherTransp  WorkAtHome  MeanCommute  Rent  Year  Population  \
# 126          0.9         3.7         21.0   831  2020      269366
#
#      Violent crime  Murder and nonnegligent manslaughter  Rape  Robbery  \
# 126            974                                    26   145      357
#
#      Aggravated assault  Property crime  Burglary  Larceny- theft  \
# 126                 446            7437       990            5879
#
#      Motor vehicle theft  Arson  Crime Rate per 1000 Crime Rating  \
# 126                  568     49                31.23       Medium
#
#      Days with AQI  Good Days  Moderate Days  \
# 126            274        190             82
#
#      Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 126                                    2               0                    0
#
#      Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 126               0      120                   61          44        0
#
#      Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10 Air Quality Index  \
# 126         0         134         0         140          0              Good
#
#      Diversity Index  Index           Nearest
# 126         0.465979    126  0,180,185,332,56

# %%
merged[56:57]
# Out:
#       City State      lat      lon  TotalPop    Men  Women  Hispanic  White  \
# 56  Canton    OH  40.8075 -81.3677    144372  68904  75423       2.7   78.6
#
#     Black  Native  Asian  Pacific   Income  IncomeErr  IncomePerCap  \
# 56   12.9     0.1    0.8      0.0  1413199     220336        788406
#
#     IncomePerCapErr  Poverty  ChildPoverty  Employed  Unemployment  \
# 56            99988     19.5          28.1     67132           8.6
#
#     PrivateWork  PublicWork  SelfEmployed  FamilyWork  Professional  Service  \
# 56         84.8        10.0           5.0         0.1          29.9     20.9
#
#     Office  Construction  Production  Drive  Carpool  Transit  Walk  \
# 56    24.3           8.1        16.5   83.0      9.1      2.2   1.6
#
#     OtherTransp  WorkAtHome  MeanCommute  Rent  Year  Population  \
# 56          0.9         2.8         21.0   795  2020       70139
#
#     Violent crime  Murder and nonnegligent manslaughter  Rape  Robbery  \
# 56            981                                     6   135      188
#
#     Aggravated assault  Property crime  Burglary  Larceny- theft  \
# 56                 652            3712       962            2429
#
#     Motor vehicle theft  Arson  Crime Rate per 1000 Crime Rating  \
# 56                  321     24                66.91         High
#
#     Days with AQI  Good Days  Moderate Days  \
# 56            274        194             77
#
#     Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 56                                    3               0                    0
#
#     Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 56               0      119                   64          43        0
#
#     Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10 Air Quality Index  \
# 56         0         156         0         118          0              Good
#
#     Diversity Index  Index           Nearest
# 56         0.364771     56  339,0,332,342,12

# %%
merged[332:333]
# Out:
#            City State      lat      lon  TotalPop    Men  Women  Hispanic  \
# 332  South Bend    IN  41.6767 -86.2696    146154  71510  74611      11.8
#
#      White  Black  Native  Asian  Pacific   Income  IncomeErr  IncomePerCap  \
# 332   63.4   19.8     0.3    1.4      0.1  1961154     337554       1020842
#
#      IncomePerCapErr  Poverty  ChildPoverty  Employed  Unemployment  \
# 332           156193     21.6          29.7     66627           8.0
#
#      PrivateWork  PublicWork  SelfEmployed  FamilyWork  Professional  Service  \
# 332         86.3         9.3           4.1         0.1          32.8     19.2
#
#      Office  Construction  Production  Drive  Carpool  Transit  Walk  \
# 332    23.0           6.1        18.6   80.6      9.3      1.8   3.1
#
#      OtherTransp  WorkAtHome  MeanCommute  Rent  Year  Population  \
# 332          1.5         3.2         20.2   905  2020      101944
#
#      Violent crime  Murder and nonnegligent manslaughter  Rape  Robbery  \
# 332           1357                                    14    56      267
#
#      Aggravated assault  Property crime  Burglary  Larceny- theft  \
# 332                1020            4296       867            2868
#
#      Motor vehicle theft  Arson  Crime Rate per 1000 Crime Rating  \
# 332                  561     75                55.45         High
#
#      Days with AQI  Good Days  Moderate Days  \
# 332            274        210             59
#
#      Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 332                                    4               1                    0
#
#      Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 332               0      162                   62          42        0
#
#      Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10 Air Quality Index  \
# 332         1         200         0          73          0              Good
#
#      Diversity Index  Index           Nearest
# 332         0.544714    332  138,56,355,270,0

# %%
merged[355:356]
# Out:
#        City State      lat      lon  TotalPop     Men   Women  Hispanic  \
# 355  Toledo    OH  41.6639 -83.5822    307155  148295  158807       7.9
#
#      White  Black  Native  Asian  Pacific   Income  IncomeErr  IncomePerCap  \
# 355   61.8   24.8     0.2    1.5      0.0  3780969     703194       2159177
#
#      IncomePerCapErr  Poverty  ChildPoverty  Employed  Unemployment  \
# 355           344566     25.0          32.9    134906          10.8
#
#      PrivateWork  PublicWork  SelfEmployed  FamilyWork  Professional  Service  \
# 355         84.3        11.1           4.3         0.1          29.9     21.3
#
#      Office  Construction  Production  Drive  Carpool  Transit  Walk  \
# 355    22.8           6.7        18.9   82.8      8.4      2.2   2.5
#
#      OtherTransp  WorkAtHome  MeanCommute  Rent  Year  Population  \
# 355          1.5         2.3         19.9   848  2020      273505
#
#      Violent crime  Murder and nonnegligent manslaughter  Rape  Robbery  \
# 355           2604                                    34   205      655
#
#      Aggravated assault  Property crime  Burglary  Larceny- theft  \
# 355                1710            9470      2362            6314
#
#      Motor vehicle theft  Arson  Crime Rate per 1000 Crime Rating  \
# 355                  794      0                44.15         High
#
#      Days with AQI  Good Days  Moderate Days  \
# 355            274        220             46
#
#      Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 355                                    8               0                    0
#
#      Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 355               0      136                   71          40        0
#
#      Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10 Air Quality Index  \
# 355         0         183         7          84          0              Good
#
#      Diversity Index  Index           Nearest
# 355         0.550104    355  332,0,295,270,56

# %%
merged[295:296]
# Out:
#          City State      lat      lon  TotalPop    Men  Women  Hispanic  \
# 295  Rockford    IL  42.2597 -89.0641    181096  88538  92532      16.5
#
#      White  Black  Native  Asian  Pacific   Income  IncomeErr  IncomePerCap  \
# 295   59.4   18.2     0.1    2.9      0.0  2389727     382633       1273045
#
#      IncomePerCapErr  Poverty  ChildPoverty  Employed  Unemployment  \
# 295           188501     19.5          25.6     78877          12.4
#
#      PrivateWork  PublicWork  SelfEmployed  FamilyWork  Professional  Service  \
# 295         85.2         9.8           4.6         0.1          28.7     19.8
#
#      Office  Construction  Production  Drive  Carpool  Transit  Walk  \
# 295    22.8           6.1        22.2   81.4     10.5      1.7   1.1
#
#      OtherTransp  WorkAtHome  MeanCommute  Rent  Year  Population  \
# 295          1.5         3.4         21.0   859  2020      145719
#
#      Violent crime  Murder and nonnegligent manslaughter  Rape  Robbery  \
# 295           1711                                    14   125      282
#
#      Aggravated assault  Property crime  Burglary  Larceny- theft  \
# 295                1290            4848      1001            3458
#
#      Motor vehicle theft  Arson  Crime Rate per 1000 Crime Rating  \
# 295                  389     70                45.01         High
#
#      Days with AQI  Good Days  Moderate Days  \
# 295            274        213             60
#
#      Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 295                                    1               0                    0
#
#      Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 295               0      101                   60          40        0
#
#      Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10 Air Quality Index  \
# 295         0         132         0         142          0              Good
#
#      Diversity Index  Index          Nearest
# 295         0.585976    295  0,332,355,93,56

# %% [markdown]
# ### DROP COLUMNS

# %%
merged = merged.drop(columns=['Index'], axis=1)

# %%
merged.head()
# Out:
#           City State      lat       lon  TotalPop     Men   Women  Hispanic  \
# 0        Akron    OH  41.0798  -81.5219    267782  129623  138086       1.9
# 1       Albany    GA  31.5776  -84.1762     93421   43571   49835       2.8
# 2       Albany    NY  42.6664  -73.7987    147794   70664   77096       7.8
# 3       Albany    OR  44.6274 -123.0966     61555   30378   31168      11.4
# 4  Albuquerque    NM  35.1053 -106.6464    632240  309415  322758      50.4
#
#    White  Black  Native  Asian  Pacific   Income  IncomeErr  IncomePerCap  \
# 0   67.4   23.2     0.2    3.6      0.0  3068406     504125       1732548
# 1   29.2   65.2     0.1    0.9      0.0  1025141     199233        547674
# 2   60.3   20.1     0.1    7.6      0.0  1917135     331452       1102265
# 3   82.7    0.6     0.7    1.9      0.1   542299      75753        268177
# 4   38.5    2.5     4.0    2.4      0.1  7693803    1270581       4099669
#
#    IncomePerCapErr  Poverty  ChildPoverty  Employed  Unemployment  \
# 0           258991     19.6          26.2    126247           8.5
# 1            89500     29.6          41.9     35704          16.2
# 2           158632     17.4          17.8     74293           6.6
# 3            35254     14.3          18.6     27721           8.2
# 4           581026     18.2          24.8    292907           6.8
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Professional  Service  \
# 0         85.4        10.3           4.1         0.1          32.3     19.8
# 1         71.9        23.7           4.1         0.1          30.7     21.4
# 2         71.6        24.3           3.9         0.0          42.9     20.5
# 3         78.5        15.9           5.4         0.1          33.3     18.4
# 4         74.5        19.6           5.6         0.2          39.8     20.0
#
#    Office  Construction  Production  Drive  Carpool  Transit  Walk  \
# 0    25.3           6.6        15.6   83.3      8.5      3.1   1.6
# 1    23.1           8.1        16.3   78.1     12.4      1.8   2.3
# 2    25.2           4.6         6.6   70.4      7.2     10.1   7.3
# 3    22.7           9.9        15.5   79.0     10.7      0.3   2.6
# 4    24.0           8.3         7.7   80.2      9.1      1.8   1.8
#
#    OtherTransp  WorkAtHome  MeanCommute  Rent  Year  Population  \
# 0          0.6         2.7         21.9   911  2020      197882
# 1          0.7         4.3         19.1   814  2020       74989
# 2          1.7         2.9         18.9  1205  2020       97221
# 3          2.0         5.1         20.8  1197  2020       54993
# 4          2.5         4.3         21.7  1013  2020      561920
#
#    Violent crime  Murder and nonnegligent manslaughter  Rape  Robbery  \
# 0           1782                                    27   181      328
# 1            790                                    12    32      165
# 2            736                                     4    60      189
# 3             70                                     1    10       16
# 4           7596                                    84   486     1699
#
#    Aggravated assault  Property crime  Burglary  Larceny- theft  \
# 0                1246            6568      1686            4305
# 1                 581            3452       729            2489
# 2                 483            2919       445            2315
# 3                  43            1467       128            1242
# 4                5327           26059         0           20634
#
#    Motor vehicle theft  Arson  Crime Rate per 1000 Crime Rating  \
# 0                  577     65                42.20         High
# 1                  234     17                56.57         High
# 2                  159     16                37.59       Medium
# 3                   97     17                27.95       Medium
# 4                 5425     98                59.89         High
#
#    Days with AQI  Good Days  Moderate Days  \
# 0            274        203             68
# 1            244        182             60
# 2            274        240             34
# 3            182        161             21
# 4            183        101             82
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    3               0                    0
# 1                                    2               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# 0               0      107                   63          43        0
# 1               0      114                   63          37        0
# 2               0       75                   53          39        1
# 3               0       70                   51          19        0
# 4               0      100                   65          50        1
#
#    Days NO2  Days Ozone  Days SO2  Days PM2.5  Days PM10 Air Quality Index  \
# 0         0         132         0         142          0              Good
# 1         0           0         0         244          0              Good
# 2         0         169         0         104          0              Good
# 3         0           0         0         182          0              Good
# 4         0         127         0          25         30              Good
#
#    Diversity Index              Nearest
# 0         0.490241   126,56,332,355,295
# 1         0.488771  162,372,139,351,249
# 2         0.584133   319,358,336,145,79
# 3         0.302632   29,132,230,383,202
# 4         0.594958  359,258,386,360,127

# %% [markdown]
# ### SAVE

# %%
merged.to_csv('nn_model.csv', index=False)

# %% [markdown]
# ### UPDATE DATABASE

# %%
# df = pd.read_csv('nn_model.csv')

# %%
# df.to_sql("data", con=engine, method='multi', if_exists='replace')

# %%
# pd.read_sql('data', con=engine)
