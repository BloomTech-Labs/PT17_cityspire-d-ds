# %%
import json
import requests

#libraries

# %%
api_key = "a0356faa6a92f9f91a3214411a107772"

#api key can be generated again if required.

# %%
def get_weather(lat,long):
    '''
    
    # parameters of JSON output. All parameters are in imperial units.
    # FYI - this API can only do a max. of 60 Calls / minute.
    
    coord
        coord.lon City geo location, longitude
        coord.lat City geo location, latitude
    weather (more info Weather condition codes)
        weather.id Weather condition id
        weather.main Group of weather parameters (Rain, Snow, Extreme etc.)
        weather.description Weather condition within the group. You can get the output in your language. Learn more
        weather.icon Weather icon id
    base Internal parameter
    main
        main.temp Temperature. Unit Default: Kelvin, Metric: Celsius, Imperial: Fahrenheit.
        main.feels_like Temperature. This temperature parameter accounts for the human perception of weather. Unit Default: Kelvin, Metric: Celsius, Imperial: Fahrenheit.
        main.pressure Atmospheric pressure (on the sea level, if there is no sea_level or grnd_level data), hPa
        main.humidity Humidity, %
        main.temp_min Minimum temperature at the moment. This is minimal currently observed temperature (within large megalopolises and urban areas). Unit Default: Kelvin, Metric: Celsius, Imperial: Fahrenheit.
        main.temp_max Maximum temperature at the moment. This is maximal currently observed temperature (within large megalopolises and urban areas). Unit Default: Kelvin, Metric: Celsius, Imperial: Fahrenheit.
        main.sea_level Atmospheric pressure on the sea level, hPa
        main.grnd_level Atmospheric pressure on the ground level, hPa
    wind
        wind.speed Wind speed. Unit Default: meter/sec, Metric: meter/sec, Imperial: miles/hour.
        wind.deg Wind direction, degrees (meteorological)
        wind.gust Wind gust. Unit Default: meter/sec, Metric: meter/sec, Imperial: miles/hour
    clouds
        clouds.all Cloudiness, %
    rain
        rain.1h Rain volume for the last 1 hour, mm
        rain.3h Rain volume for the last 3 hours, mm
    snow
        snow.1h Snow volume for the last 1 hour, mm
        snow.3h Snow volume for the last 3 hours, mm
    dt Time of data calculation, unix, UTC
    sys
        sys.type Internal parameter
        sys.id Internal parameter
        sys.message Internal parameter
        sys.country Country code (GB, JP etc.)
        sys.sunrise Sunrise time, unix, UTC
        sys.sunset Sunset time, unix, UTC
    timezone Shift in seconds from UTC
    id City ID
    name City name
    cod Internal parameter

'''
    
    
    
    link = "https://api.openweathermap.org/data/2.5/weather?lat=%s&lon=%s&appid=%s&units=imperial" % (lat, lon, api_key)
    response = requests.get(url)
    data = json.loads(response.text)
    return data

# %%
get_weather(48.208176,16.373819)
# Out:
# {'lat': 48.2082,
#  'lon': 16.3738,
#  'timezone': 'Europe/Vienna',
#  'timezone_offset': 7200,
#  'current': {'dt': 1617751993,
#   'sunrise': 1617769216,
#   'sunset': 1617816753,
#   'temp': 32.45,
#   'feels_like': 26.1,
#   'pressure': 1008,
#   'humidity': 74,
#   'dew_point': 25.9,
#   'uvi': 0,
#   'clouds': 20,
#   'visibility': 10000,
#   'wind_speed': 6.91,
#   'wind_deg': 230,
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}]},
#  'minutely': [{'dt': 1617752040, 'precipitation': 0},
#   {'dt': 1617752100, 'precipitation': 0},
#   {'dt': 1617752160, 'precipitation': 0},
#   {'dt': 1617752220, 'precipitation': 0},
#   {'dt': 1617752280, 'precipitation': 0},
#   {'dt': 1617752340, 'precipitation': 0},
#   {'dt': 1617752400, 'precipitation': 0},
#   {'dt': 1617752460, 'precipitation': 0},
#   {'dt': 1617752520, 'precipitation': 0},
#   {'dt': 1617752580, 'precipitation': 0},
#   {'dt': 1617752640, 'precipitation': 0},
#   {'dt': 1617752700, 'precipitation': 0},
#   {'dt': 1617752760, 'precipitation': 0},
#   {'dt': 1617752820, 'precipitation': 0},
#   {'dt': 1617752880, 'precipitation': 0},
#   {'dt': 1617752940, 'precipitation': 0},
#   {'dt': 1617753000, 'precipitation': 0},
#   {'dt': 1617753060, 'precipitation': 0},
#   {'dt': 1617753120, 'precipitation': 0},
#   {'dt': 1617753180, 'precipitation': 0},
#   {'dt': 1617753240, 'precipitation': 0},
#   {'dt': 1617753300, 'precipitation': 0},
#   {'dt': 1617753360, 'precipitation': 0},
#   {'dt': 1617753420, 'precipitation': 0},
#   {'dt': 1617753480, 'precipitation': 0},
#   {'dt': 1617753540, 'precipitation': 0},
#   {'dt': 1617753600, 'precipitation': 0},
#   {'dt': 1617753660, 'precipitation': 0},
#   {'dt': 1617753720, 'precipitation': 0},
#   {'dt': 1617753780, 'precipitation': 0},
#   {'dt': 1617753840, 'precipitation': 0},
#   {'dt': 1617753900, 'precipitation': 0},
#   {'dt': 1617753960, 'precipitation': 0},
#   {'dt': 1617754020, 'precipitation': 0},
#   {'dt': 1617754080, 'precipitation': 0},
#   {'dt': 1617754140, 'precipitation': 0},
#   {'dt': 1617754200, 'precipitation': 0},
#   {'dt': 1617754260, 'precipitation': 0},
#   {'dt': 1617754320, 'precipitation': 0},
#   {'dt': 1617754380, 'precipitation': 0},
#   {'dt': 1617754440, 'precipitation': 0},
#   {'dt': 1617754500, 'precipitation': 0},
#   {'dt': 1617754560, 'precipitation': 0},
#   {'dt': 1617754620, 'precipitation': 0},
#   {'dt': 1617754680, 'precipitation': 0},
#   {'dt': 1617754740, 'precipitation': 0},
#   {'dt': 1617754800, 'precipitation': 0},
#   {'dt': 1617754860, 'precipitation': 0},
#   {'dt': 1617754920, 'precipitation': 0},
#   {'dt': 1617754980, 'precipitation': 0},
#   {'dt': 1617755040, 'precipitation': 0},
#   {'dt': 1617755100, 'precipitation': 0},
#   {'dt': 1617755160, 'precipitation': 0},
#   {'dt': 1617755220, 'precipitation': 0},
#   {'dt': 1617755280, 'precipitation': 0},
#   {'dt': 1617755340, 'precipitation': 0},
#   {'dt': 1617755400, 'precipitation': 0},
#   {'dt': 1617755460, 'precipitation': 0},
#   {'dt': 1617755520, 'precipitation': 0},
#   {'dt': 1617755580, 'precipitation': 0},
#   {'dt': 1617755640, 'precipitation': 0}],
#  'hourly': [{'dt': 1617750000,
#    'temp': 32.45,
#    'feels_like': 25.09,
#    'pressure': 1008,
#    'humidity': 74,
#    'dew_point': 25.9,
#    'uvi': 0,
#    'clouds': 20,
#    'visibility': 10000,
#    'wind_speed': 8.5,
#    'wind_deg': 278,
#    'wind_gust': 20.67,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'pop': 0},
#   {'dt': 1617753600,
#    'temp': 33.12,
#    'feels_like': 25.66,
#    'pressure': 1008,
#    'humidity': 71,
#    'dew_point': 25.59,
#    'uvi': 0,
#    'clouds': 27,
#    'visibility': 10000,
#    'wind_speed': 8.95,
#    'wind_deg': 278,
#    'wind_gust': 21.63,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1617757200,
#    'temp': 33.26,
#    'feels_like': 25.56,
#    'pressure': 1009,
#    'humidity': 69,
#    'dew_point': 25.11,
#    'uvi': 0,
#    'clouds': 40,
#    'visibility': 10000,
#    'wind_speed': 9.48,
#    'wind_deg': 278,
#    'wind_gust': 21.88,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1617760800,
#    'temp': 33.13,
#    'feels_like': 25,
#    'pressure': 1010,
#    'humidity': 71,
#    'dew_point': 25.59,
#    'uvi': 0,
#    'clouds': 36,
#    'visibility': 10000,
#    'wind_speed': 10.27,
#    'wind_deg': 276,
#    'wind_gust': 22.15,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1617764400,
#    'temp': 32.65,
#    'feels_like': 24.46,
#    'pressure': 1010,
#    'humidity': 74,
#    'dew_point': 26.06,
#    'uvi': 0,
#    'clouds': 30,
#    'visibility': 10000,
#    'wind_speed': 10.13,
#    'wind_deg': 277,
#    'wind_gust': 22.21,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1617768000,
#    'temp': 32.23,
#    'feels_like': 24.03,
#    'pressure': 1010,
#    'humidity': 76,
#    'dew_point': 25.18,
#    'uvi': 0,
#    'clouds': 26,
#    'visibility': 10000,
#    'wind_speed': 10,
#    'wind_deg': 280,
#    'wind_gust': 22.41,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0.02},
#   {'dt': 1617771600,
#    'temp': 32.43,
#    'feels_like': 24.42,
#    'pressure': 1011,
#    'humidity': 76,
#    'dew_point': 25.29,
#    'uvi': 0.08,
#    'clouds': 25,
#    'visibility': 10000,
#    'wind_speed': 9.69,
#    'wind_deg': 283,
#    'wind_gust': 22.26,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0.02},
#   {'dt': 1617775200,
#    'temp': 34.57,
#    'feels_like': 26.37,
#    'pressure': 1012,
#    'humidity': 71,
#    'dew_point': 25.74,
#    'uvi': 0.33,
#    'clouds': 25,
#    'visibility': 10000,
#    'wind_speed': 11.21,
#    'wind_deg': 283,
#    'wind_gust': 21.45,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0.02},
#   {'dt': 1617778800,
#    'temp': 36.39,
#    'feels_like': 28.11,
#    'pressure': 1012,
#    'humidity': 64,
#    'dew_point': 25.11,
#    'uvi': 0.69,
#    'clouds': 39,
#    'visibility': 10000,
#    'wind_speed': 12.5,
#    'wind_deg': 292,
#    'wind_gust': 19.93,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0.04},
#   {'dt': 1617782400,
#    'temp': 37.22,
#    'feels_like': 29.3,
#    'pressure': 1012,
#    'humidity': 67,
#    'dew_point': 26.91,
#    'uvi': 1.29,
#    'clouds': 60,
#    'visibility': 9581,
#    'wind_speed': 12.1,
#    'wind_deg': 301,
#    'wind_gust': 18.72,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.24,
#    'snow': {'1h': 0.14}},
#   {'dt': 1617786000,
#    'temp': 40.19,
#    'feels_like': 33.01,
#    'pressure': 1012,
#    'humidity': 51,
#    'dew_point': 23.22,
#    'uvi': 1.91,
#    'clouds': 70,
#    'visibility': 10000,
#    'wind_speed': 12.19,
#    'wind_deg': 305,
#    'wind_gust': 18.81,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.39,
#    'snow': {'1h': 0.26}},
#   {'dt': 1617789600,
#    'temp': 41.59,
#    'feels_like': 34.57,
#    'pressure': 1013,
#    'humidity': 46,
#    'dew_point': 21.97,
#    'uvi': 2.32,
#    'clouds': 78,
#    'visibility': 10000,
#    'wind_speed': 12.8,
#    'wind_deg': 300,
#    'wind_gust': 19.51,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.47},
#   {'dt': 1617793200,
#    'temp': 42.89,
#    'feels_like': 35.96,
#    'pressure': 1013,
#    'humidity': 38,
#    'dew_point': 18.23,
#    'uvi': 2.47,
#    'clouds': 82,
#    'visibility': 10000,
#    'wind_speed': 13.6,
#    'wind_deg': 298,
#    'wind_gust': 19.66,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.47},
#   {'dt': 1617796800,
#    'temp': 41.99,
#    'feels_like': 34.65,
#    'pressure': 1013,
#    'humidity': 42,
#    'dew_point': 18.86,
#    'uvi': 2.27,
#    'clouds': 85,
#    'visibility': 10000,
#    'wind_speed': 14.12,
#    'wind_deg': 281,
#    'wind_gust': 21.03,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.58},
#   {'dt': 1617800400,
#    'temp': 41.68,
#    'feels_like': 33.85,
#    'pressure': 1014,
#    'humidity': 44,
#    'dew_point': 20.48,
#    'uvi': 1.69,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 15.48,
#    'wind_deg': 277,
#    'wind_gust': 22.7,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.47},
#   {'dt': 1617804000,
#    'temp': 41.31,
#    'feels_like': 33.44,
#    'pressure': 1014,
#    'humidity': 47,
#    'dew_point': 22.14,
#    'uvi': 1.12,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 15.23,
#    'wind_deg': 287,
#    'wind_gust': 22.86,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.38},
#   {'dt': 1617807600,
#    'temp': 41.67,
#    'feels_like': 34.11,
#    'pressure': 1015,
#    'humidity': 43,
#    'dew_point': 20.39,
#    'uvi': 0.59,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 14.54,
#    'wind_deg': 291,
#    'wind_gust': 22.93,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.32},
#   {'dt': 1617811200,
#    'temp': 40.51,
#    'feels_like': 33.06,
#    'pressure': 1015,
#    'humidity': 46,
#    'dew_point': 21.22,
#    'uvi': 0.3,
#    'clouds': 92,
#    'visibility': 10000,
#    'wind_speed': 13.24,
#    'wind_deg': 292,
#    'wind_gust': 23.47,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.34,
#    'snow': {'1h': 0.17}},
#   {'dt': 1617814800,
#    'temp': 38.98,
#    'feels_like': 31.06,
#    'pressure': 1016,
#    'humidity': 48,
#    'dew_point': 20.66,
#    'uvi': 0,
#    'clouds': 83,
#    'visibility': 10000,
#    'wind_speed': 13.38,
#    'wind_deg': 286,
#    'wind_gust': 23.22,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.26},
#   {'dt': 1617818400,
#    'temp': 37.08,
#    'feels_like': 29.07,
#    'pressure': 1017,
#    'humidity': 52,
#    'dew_point': 20.86,
#    'uvi': 0,
#    'clouds': 72,
#    'visibility': 10000,
#    'wind_speed': 12.26,
#    'wind_deg': 282,
#    'wind_gust': 24.2,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0.18},
#   {'dt': 1617822000,
#    'temp': 36.07,
#    'feels_like': 28.4,
#    'pressure': 1017,
#    'humidity': 57,
#    'dew_point': 22.06,
#    'uvi': 0,
#    'clouds': 15,
#    'visibility': 10000,
#    'wind_speed': 10.83,
#    'wind_deg': 273,
#    'wind_gust': 24.23,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'pop': 0.02},
#   {'dt': 1617825600,
#    'temp': 35.51,
#    'feels_like': 27.46,
#    'pressure': 1017,
#    'humidity': 64,
#    'dew_point': 24.06,
#    'uvi': 0,
#    'clouds': 28,
#    'visibility': 10000,
#    'wind_speed': 11.34,
#    'wind_deg': 272,
#    'wind_gust': 26.93,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0.02},
#   {'dt': 1617829200,
#    'temp': 34.79,
#    'feels_like': 26.11,
#    'pressure': 1017,
#    'humidity': 74,
#    'dew_point': 27.03,
#    'uvi': 0,
#    'clouds': 45,
#    'visibility': 10000,
#    'wind_speed': 12.41,
#    'wind_deg': 272,
#    'wind_gust': 28.25,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0.02},
#   {'dt': 1617832800,
#    'temp': 34.97,
#    'feels_like': 26.2,
#    'pressure': 1017,
#    'humidity': 77,
#    'dew_point': 28.31,
#    'uvi': 0,
#    'clouds': 43,
#    'visibility': 10000,
#    'wind_speed': 12.77,
#    'wind_deg': 273,
#    'wind_gust': 28.59,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0.02},
#   {'dt': 1617836400,
#    'temp': 34.57,
#    'feels_like': 25.12,
#    'pressure': 1018,
#    'humidity': 83,
#    'dew_point': 29.61,
#    'uvi': 0,
#    'clouds': 47,
#    'visibility': 10000,
#    'wind_speed': 14.34,
#    'wind_deg': 274,
#    'wind_gust': 29.86,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.3,
#    'snow': {'1h': 0.13}},
#   {'dt': 1617840000,
#    'temp': 35.28,
#    'feels_like': 25.84,
#    'pressure': 1018,
#    'humidity': 86,
#    'dew_point': 31.24,
#    'uvi': 0,
#    'clouds': 56,
#    'visibility': 10000,
#    'wind_speed': 14.81,
#    'wind_deg': 280,
#    'wind_gust': 31.83,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.38,
#    'snow': {'1h': 0.15}},
#   {'dt': 1617843600,
#    'temp': 36.34,
#    'feels_like': 27.28,
#    'pressure': 1018,
#    'humidity': 82,
#    'dew_point': 31.01,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 14.56,
#    'wind_deg': 287,
#    'wind_gust': 30.04,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'pop': 0.35,
#    'snow': {'1h': 0.15}},
#   {'dt': 1617847200,
#    'temp': 35.1,
#    'feels_like': 26.6,
#    'pressure': 1019,
#    'humidity': 91,
#    'dew_point': 32.27,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 2677,
#    'wind_speed': 12.19,
#    'wind_deg': 281,
#    'wind_gust': 27.2,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.37,
#    'rain': {'1h': 0.74}},
#   {'dt': 1617850800,
#    'temp': 35.28,
#    'feels_like': 25.97,
#    'pressure': 1019,
#    'humidity': 79,
#    'dew_point': 29.34,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 14.45,
#    'wind_deg': 283,
#    'wind_gust': 27.63,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.41},
#   {'dt': 1617854400,
#    'temp': 34.3,
#    'feels_like': 24.69,
#    'pressure': 1020,
#    'humidity': 76,
#    'dew_point': 27.18,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 14.58,
#    'wind_deg': 288,
#    'wind_gust': 30.58,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.37},
#   {'dt': 1617858000,
#    'temp': 33.67,
#    'feels_like': 23.92,
#    'pressure': 1021,
#    'humidity': 72,
#    'dew_point': 25.43,
#    'uvi': 0.1,
#    'clouds': 85,
#    'visibility': 10000,
#    'wind_speed': 14.5,
#    'wind_deg': 288,
#    'wind_gust': 30.94,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.36},
#   {'dt': 1617861600,
#    'temp': 35.1,
#    'feels_like': 25.54,
#    'pressure': 1022,
#    'humidity': 68,
#    'dew_point': 25.43,
#    'uvi': 0.4,
#    'clouds': 73,
#    'visibility': 10000,
#    'wind_speed': 15.05,
#    'wind_deg': 291,
#    'wind_gust': 30.51,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.28},
#   {'dt': 1617865200,
#    'temp': 37.45,
#    'feels_like': 28.51,
#    'pressure': 1023,
#    'humidity': 65,
#    'dew_point': 26.35,
#    'uvi': 1.02,
#    'clouds': 13,
#    'visibility': 10000,
#    'wind_speed': 15.19,
#    'wind_deg': 290,
#    'wind_gust': 27.94,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1617868800,
#    'temp': 39.49,
#    'feels_like': 31.1,
#    'pressure': 1023,
#    'humidity': 58,
#    'dew_point': 25.84,
#    'uvi': 1.88,
#    'clouds': 16,
#    'visibility': 10000,
#    'wind_speed': 15.26,
#    'wind_deg': 297,
#    'wind_gust': 26.49,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1617872400,
#    'temp': 40.71,
#    'feels_like': 32.52,
#    'pressure': 1023,
#    'humidity': 52,
#    'dew_point': 24.42,
#    'uvi': 2.79,
#    'clouds': 39,
#    'visibility': 10000,
#    'wind_speed': 15.79,
#    'wind_deg': 298,
#    'wind_gust': 25.01,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'pop': 0.3,
#    'snow': {'1h': 0.25}},
#   {'dt': 1617876000,
#    'temp': 41.63,
#    'feels_like': 33.69,
#    'pressure': 1024,
#    'humidity': 50,
#    'dew_point': 23.9,
#    'uvi': 2.83,
#    'clouds': 53,
#    'visibility': 8034,
#    'wind_speed': 15.82,
#    'wind_deg': 296,
#    'wind_gust': 24.25,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.22},
#   {'dt': 1617879600,
#    'temp': 42.12,
#    'feels_like': 34.56,
#    'pressure': 1024,
#    'humidity': 48,
#    'dew_point': 23.52,
#    'uvi': 3.02,
#    'clouds': 61,
#    'visibility': 9693,
#    'wind_speed': 14.94,
#    'wind_deg': 298,
#    'wind_gust': 24.29,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.28},
#   {'dt': 1617883200,
#    'temp': 43.65,
#    'feels_like': 36.39,
#    'pressure': 1024,
#    'humidity': 44,
#    'dew_point': 22.82,
#    'uvi': 2.78,
#    'clouds': 67,
#    'visibility': 10000,
#    'wind_speed': 15.39,
#    'wind_deg': 303,
#    'wind_gust': 24.58,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.28},
#   {'dt': 1617886800,
#    'temp': 44.73,
#    'feels_like': 37.89,
#    'pressure': 1024,
#    'humidity': 40,
#    'dew_point': 21.54,
#    'uvi': 2.51,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 15.03,
#    'wind_deg': 305,
#    'wind_gust': 24.02,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.22},
#   {'dt': 1617890400,
#    'temp': 45.32,
#    'feels_like': 38.75,
#    'pressure': 1024,
#    'humidity': 37,
#    'dew_point': 20.14,
#    'uvi': 1.65,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 14.65,
#    'wind_deg': 310,
#    'wind_gust': 22.35,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.18},
#   {'dt': 1617894000,
#    'temp': 45.25,
#    'feels_like': 39.18,
#    'pressure': 1024,
#    'humidity': 37,
#    'dew_point': 20.43,
#    'uvi': 0.85,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 12.82,
#    'wind_deg': 311,
#    'wind_gust': 20.2,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.14},
#   {'dt': 1617897600,
#    'temp': 44.67,
#    'feels_like': 39.22,
#    'pressure': 1025,
#    'humidity': 41,
#    'dew_point': 21.63,
#    'uvi': 0.37,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 10.56,
#    'wind_deg': 309,
#    'wind_gust': 18.3,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.14},
#   {'dt': 1617901200,
#    'temp': 42.17,
#    'feels_like': 37.08,
#    'pressure': 1026,
#    'humidity': 47,
#    'dew_point': 23.02,
#    'uvi': 0,
#    'clouds': 77,
#    'visibility': 10000,
#    'wind_speed': 8.3,
#    'wind_deg': 301,
#    'wind_gust': 16.06,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.14},
#   {'dt': 1617904800,
#    'temp': 39.25,
#    'feels_like': 34.65,
#    'pressure': 1027,
#    'humidity': 55,
#    'dew_point': 23.77,
#    'uvi': 0,
#    'clouds': 66,
#    'visibility': 10000,
#    'wind_speed': 6.33,
#    'wind_deg': 291,
#    'wind_gust': 15.99,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0.14},
#   {'dt': 1617908400,
#    'temp': 37.89,
#    'feels_like': 34.07,
#    'pressure': 1027,
#    'humidity': 59,
#    'dew_point': 24.51,
#    'uvi': 0,
#    'clouds': 7,
#    'visibility': 10000,
#    'wind_speed': 4.9,
#    'wind_deg': 281,
#    'wind_gust': 12.93,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1617912000,
#    'temp': 36.93,
#    'feels_like': 33.67,
#    'pressure': 1028,
#    'humidity': 64,
#    'dew_point': 25.25,
#    'uvi': 0,
#    'clouds': 9,
#    'visibility': 10000,
#    'wind_speed': 4.09,
#    'wind_deg': 265,
#    'wind_gust': 9.17,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1617915600,
#    'temp': 36.16,
#    'feels_like': 33.19,
#    'pressure': 1028,
#    'humidity': 67,
#    'dew_point': 25.86,
#    'uvi': 0,
#    'clouds': 11,
#    'visibility': 10000,
#    'wind_speed': 3.71,
#    'wind_deg': 257,
#    'wind_gust': 7.11,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'pop': 0},
#   {'dt': 1617919200,
#    'temp': 35.55,
#    'feels_like': 35.55,
#    'pressure': 1028,
#    'humidity': 69,
#    'dew_point': 26.15,
#    'uvi': 0,
#    'clouds': 12,
#    'visibility': 10000,
#    'wind_speed': 2.95,
#    'wind_deg': 253,
#    'wind_gust': 4.18,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'pop': 0}],
#  'daily': [{'dt': 1617789600,
#    'sunrise': 1617769216,
#    'sunset': 1617816753,
#    'temp': {'day': 41.59,
#     'min': 32.23,
#     'max': 42.89,
#     'night': 34.79,
#     'eve': 40.51,
#     'morn': 32.23},
#    'feels_like': {'day': 34.57, 'night': 24.03, 'eve': 33.06, 'morn': 24.03},
#    'pressure': 1013,
#    'humidity': 46,
#    'dew_point': 21.97,
#    'wind_speed': 12.8,
#    'wind_deg': 300,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 78,
#    'pop': 0.58,
#    'snow': 0.57,
#    'uvi': 2.47},
#   {'dt': 1617876000,
#    'sunrise': 1617855495,
#    'sunset': 1617903240,
#    'temp': {'day': 41.63,
#     'min': 33.67,
#     'max': 45.32,
#     'night': 36.16,
#     'eve': 44.67,
#     'morn': 34.3},
#    'feels_like': {'day': 33.69, 'night': 24.69, 'eve': 39.22, 'morn': 24.69},
#    'pressure': 1024,
#    'humidity': 50,
#    'dew_point': 23.9,
#    'wind_speed': 15.82,
#    'wind_deg': 296,
#    'weather': [{'id': 616,
#      'main': 'Snow',
#      'description': 'rain and snow',
#      'icon': '13d'}],
#    'clouds': 53,
#    'pop': 0.41,
#    'rain': 0.74,
#    'snow': 0.68,
#    'uvi': 3.02},
#   {'dt': 1617962400,
#    'sunrise': 1617941775,
#    'sunset': 1617989727,
#    'temp': {'day': 51.78,
#     'min': 33.28,
#     'max': 58.28,
#     'night': 47.91,
#     'eve': 58.28,
#     'morn': 33.28},
#    'feels_like': {'day': 48.6, 'night': 28.18, 'eve': 55.51, 'morn': 28.18},
#    'pressure': 1022,
#    'humidity': 41,
#    'dew_point': 28.63,
#    'wind_speed': 8.75,
#    'wind_deg': 155,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': 37,
#    'pop': 0,
#    'uvi': 4.32},
#   {'dt': 1618048800,
#    'sunrise': 1618028055,
#    'sunset': 1618076214,
#    'temp': {'day': 52.07,
#     'min': 40.69,
#     'max': 61,
#     'night': 50.09,
#     'eve': 61,
#     'morn': 40.69},
#    'feels_like': {'day': 49.6, 'night': 40.69, 'eve': 58.68, 'morn': 40.69},
#    'pressure': 1019,
#    'humidity': 56,
#    'dew_point': 36.7,
#    'wind_speed': 9.48,
#    'wind_deg': 133,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': 40,
#    'pop': 0,
#    'uvi': 4.17},
#   {'dt': 1618135200,
#    'sunrise': 1618114336,
#    'sunset': 1618162701,
#    'temp': {'day': 56.1,
#     'min': 46.35,
#     'max': 62.74,
#     'night': 50.86,
#     'eve': 62.74,
#     'morn': 46.35},
#    'feels_like': {'day': 53.91, 'night': 40.59, 'eve': 60.87, 'morn': 40.59},
#    'pressure': 1016,
#    'humidity': 53,
#    'dew_point': 39.13,
#    'wind_speed': 6.58,
#    'wind_deg': 175,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': 99,
#    'pop': 0,
#    'uvi': 3.46},
#   {'dt': 1618221600,
#    'sunrise': 1618200618,
#    'sunset': 1618249188,
#    'temp': {'day': 52.84,
#     'min': 44.01,
#     'max': 55.15,
#     'night': 44.01,
#     'eve': 50.97,
#     'morn': 46.56},
#    'feels_like': {'day': 51.03, 'night': 45.64, 'eve': 49.01, 'morn': 45.64},
#    'pressure': 1024,
#    'humidity': 68,
#    'dew_point': 42.28,
#    'wind_speed': 10.04,
#    'wind_deg': 328,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': 86,
#    'pop': 0,
#    'uvi': 4},
#   {'dt': 1618308000,
#    'sunrise': 1618286900,
#    'sunset': 1618335675,
#    'temp': {'day': 47.16,
#     'min': 39.72,
#     'max': 47.16,
#     'night': 39.72,
#     'eve': 43.79,
#     'morn': 42.03},
#    'feels_like': {'day': 44.35, 'night': 39.7, 'eve': 38.77, 'morn': 39.7},
#    'pressure': 1024,
#    'humidity': 76,
#    'dew_point': 39.85,
#    'wind_speed': 5.88,
#    'wind_deg': 319,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 4.35,
#    'uvi': 4},
#   {'dt': 1618394400,
#    'sunrise': 1618373183,
#    'sunset': 1618422162,
#    'temp': {'day': 38.14,
#     'min': 37.92,
#     'max': 39.02,
#     'night': 37.92,
#     'eve': 39.02,
#     'morn': 38.37},
#    'feels_like': {'day': 31.28, 'night': 31.19, 'eve': 31.87, 'morn': 31.19},
#    'pressure': 1022,
#    'humidity': 95,
#    'dew_point': 36.77,
#    'wind_speed': 10.11,
#    'wind_deg': 312,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 10.9,
#    'uvi': 4}],
#  'alerts': [{'sender_name': 'ZAMG Zentralanstalt für Meteorologie und Geodynamik',
#    'event': 'Coldwarning',
#    'start': 1617746400,
#    'end': 1617832799,
#    'description': ' \n\t\t\tIncreased cold stress must be expected.\n\t\t'},
#   {'sender_name': 'ZAMG Zentralanstalt für Meteorologie und Geodynamik',
#    'event': 'Coldwarning',
#    'start': 1617832800,
#    'end': 1617919199,
#    'description': ' \n\t\t\tIncreased cold stress must be expected.\n\t\t'},
#   {'sender_name': 'ZAMG Zentralanstalt für Meteorologie und Geodynamik',
#    'event': 'Coldwarning',
#    'start': 1617919200,
#    'end': 1618005599,
#    'description': ' \n\t\t\tIncreased cold stress must be expected.\n\t\t'},
#   {'sender_name': 'ZAMG Zentralanstalt für Meteorologie und Geodynamik',
#    'event': 'Stormwarning',
#    'start': 1617782400,
#    'end': 1617876000,
#    'description': ' \n\t\t\tGusts of 80 kph are possible.\n\t\t'}]}
